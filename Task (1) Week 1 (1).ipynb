# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd 

df = pd.read_csv(r"C:\Users\s3odk\Downloads\Task (1) Dataset.csv")

# %%
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %%
df.sample(10)
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 88      7:40:00      Monday              18-30          Male
# 1546   17:48:00     Tuesday              31-50          Male
# 3375   16:25:00      Monday              31-50          Male
# 904    19:00:00   Wednesday           Under 18          Male
# 5616   16:00:00     Tuesday               None          Male
# 704    17:45:00     Tuesday               None        Female
# 7497   18:29:00    Thursday              18-30          Male
# 11557  20:40:00      Friday              18-30          Male
# 7000   14:35:00   Wednesday              18-30          Male
# 248    15:55:00    Thursday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 88     Junior high school                Employee              2-5yr
# 1546   Junior high school                Employee              2-5yr
# 3375   Junior high school                Employee             5-10yr
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Handle Missing Values

# %%
df.isnull().value_counts().sum()
# Out:
# 12316

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                 4443
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df['Casualty_class'] = df['Casualty_class'].replace('na', None)





# df['Casualty_class'] = df['Casualty_class'](dtype='str')
# df['Casualty_class'].info()

# %%
df = df.replace('Unknown', None)
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday               None          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                 4443
# Sex_of_casualty                4443
# Age_band_of_casualty           4443
# ...

# %%
df = df.replace('Unknown', None)

# %%
df = df.replace('na', None)

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver             1548
# Sex_of_driver                   178
# Educational_level               841
# Vehicle_driver_relation         593
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        6811
# Defect_of_vehicle              4427
# Area_accident_occured           261
# Lanes_or_Medians                442
# Road_allignment                 142
# Types_of_Junction              1078
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions              292
# Type_of_collision               169
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                396
# Casualty_class                 4443
# Sex_of_casualty                4443
# Age_band_of_casualty           4443
# ...

# %%
# df['Casualty_class'] = df['Casualty_class'].str.replace('na', None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 df['Casualty_class'] = df['Casualty_class'].str.replace('na', None)
#
# File ~\anaconda\lib\site-packages\pandas\core\strings\accessor.py:129, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     124     msg = (
#     125         f"Cannot use .str.{func_name} with values of "
#     126         f"inferred dtype '{self._inferred_dtype}'."
#     127     )
#     128     raise TypeError(msg)
# --> 129 return func(self, *args, **kwargs)
#
# File ~\anaconda\lib\site-packages\pandas\core\strings\accessor.py:1473, in StringMethods.replace(self, pat, repl, n, case, flags, regex)
#    1471 # Check whether repl is valid (GH 13438, GH 15055)
#    1472 if not (isinstance(repl, str) or callable(repl)):
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %%
df.sample(5)
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 8872   23:54:00    Saturday              18-30          Male
# 10076  17:22:00     Tuesday            Over 51          Male
# 1180    9:00:00      Friday            Over 51          Male
# 2785   15:10:00      Sunday              18-30          Male
# 5613    9:17:00     Tuesday               None          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 8872   Junior high school                Employee                1-2
# 10076  Junior high school                Employee                 10
# 1180   Junior high school                Employee               5-10
# 2785                  NaN                     NaN               <NA>
# 5613   Junior high school                Employee                2-5
#
#         Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 8872       Stationwagen            Owner                  2-5yrs  ...
# ...

# %%
# df['Age_band_of_casualty'] = df['Age_band_of_casualty'].replace('Over ', "")
df['Age_band_of_casualty'] = df['Age_band_of_casualty'].astype("string") 
df['Age_band_of_casualty'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 12316 entries, 0 to 12315
# Series name: Age_band_of_casualty
# Non-Null Count  Dtype
# --------------  -----
# 12316 non-null  string
# dtypes: string(1)
# memory usage: 96.3 KB

# %%
df['Driving_experience'] = df['Driving_experience'].astype("string")

# %%
df['Age_band_of_casualty'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 12316 entries, 0 to 12315
# Series name: Age_band_of_casualty
# Non-Null Count  Dtype
# --------------  -----
# 12316 non-null  object
# dtypes: object(1)
# memory usage: 96.3+ KB

# %%
# df['Driving_experience'] = df['Driving_experience'].replace('Under', "" )
df['Driving_experience'] = df['Driving_experience'].str.replace(" Over"," ").str.replace("yr",'').str.replace("Above " ,'')
# df.sample(5)
df['Driving_experience']
# Out:
# 0         1-2
# 1          10
# 2         1-2
# 3        5-10
# 4         2-5
#          ...
# 12311     2-5
# 12312    5-10
# 12313    5-10
# 12314      10
# 12315    5-10
# Name: Driving_experience, Length: 12316, dtype: string

# %%
#  df["Age_band_of_driver"] =df["Age_band_of_driver"].str.replace("Over "," ") 
# df['Driving_experience'].str.replace(" Over"," ")
df["Age_band_of_driver"]
# Out:
# 0        18-30
# 1        31-50
# 2        18-30
# 3        18-30
# 4        18-30
#          ...
# 12311    31-50
# 12312     None
# 12313       51
# 12314    18-30
# 12315    18-30
# Name: Age_band_of_driver, Length: 12316, dtype: object

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver             1548
# Sex_of_driver                   178
# Educational_level               841
# Vehicle_driver_relation         593
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        6811
# Defect_of_vehicle              4427
# Area_accident_occured           261
# Lanes_or_Medians                442
# Road_allignment                 142
# Types_of_Junction              1078
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions              292
# Type_of_collision               169
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                396
# Casualty_class                 4443
# Sex_of_casualty                4443
# Age_band_of_casualty              0
# ...

# %%
# df["Casualty_class"]
df.sample(5)
# Out:
#           Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 2966  19:55:00      Sunday              31-50          Male
# 2663   7:25:00     Tuesday                 51          Male
# 2190  21:51:00   Wednesday              18-30          Male
# 1609  12:44:00   Wednesday              31-50          Male
# 421    9:05:00      Friday              31-50          Male
#
#        Educational_level Vehicle_driver_relation Driving_experience  \
# 2966  Junior high school                Employee                 10
# 2663  Junior high school                Employee                 10
# 2190  Junior high school                Employee                 10
# 1609   Above high school                Employee                 10
# 421    Elementary school                Employee            Below 1
#
#            Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 2966  Public (13?45 seats)            Owner                  2-5yrs  ...
# ...

# %% [markdown]
# ####  Missing Values

# %% [raw]
# # Cause_of_accident ,
# # df['Cause_of_accident'] =df['Cause_of_accident'].dropna()
# # df.drop(columns= 'Cause_of_accident' , inplace = True)
# df = df.dropna(subset = 'Cause_of_accident' , inplace= True)
# df.isnull().sum()

# %%
df.drop(columns= 'Cause_of_accident' , inplace = True)

# %%
# df['Cause_of_accident'] = df.dropna(subset = 'Cause_of_accident' , inplace= True)
# df.isnull().sum()

# %%
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday               None          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %%
# df['Age_band_of_driver'].fillna(df['Age_band_of_driver'].mode()[0])
# df['Age_band_of_driver'] = df['Age_band_of_driver'].astype("float") 
# df['Age_band_of_driver'] =df['Age_band_of_driver'].fillna(df['Age_band_of_driver'].mode()[0])
df["Sex_of_driver"] =df["Sex_of_driver"].fillna(df["Sex_of_driver"].mode()[0])
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               839
# Vehicle_driver_relation         593
# Driving_experience              829
# Type_of_vehicle                 946
# Owner_of_vehicle                481
# Service_year_of_vehicle        6800
# Defect_of_vehicle              4418
# Area_accident_occured           260
# Lanes_or_Medians                441
# Road_allignment                 142
# Types_of_Junction              1077
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions              291
# Type_of_collision               168
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                392
# Casualty_class                 4432
# Sex_of_casualty                4432
# Age_band_of_casualty              0
# ...

# %%
# # df["Educational_level"] =df["Educational_level"].fillna(df["Educational_level"].mode()[0])
# df["Vehicle_driver_relation"] =df["Vehicle_driver_relation"].fillna(df["Vehicle_driver_relation"].mode()[0])
# disnullull().sum()

# %%
# df['Age_band_of_driver'].info()
# df['Age_band_of_driver'].fillna(df['Age_band_of_driver'].mean())
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 12291 entries, 0 to 12315
# Series name: Age_band_of_driver
# Non-Null Count  Dtype
# --------------  -----
# 10745 non-null  object
# dtypes: object(1)
# memory usage: 192.0+ KB

# %%
df.drop(columns= 'Service_year_of_vehicle' , inplace = True)

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level                 0
# Vehicle_driver_relation           0
# Driving_experience                0
# Type_of_vehicle                 946
# Owner_of_vehicle                481
# Defect_of_vehicle              4418
# Area_accident_occured           260
# Lanes_or_Medians                441
# Road_allignment                 142
# Types_of_Junction              1077
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions              291
# Type_of_collision               168
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                392
# Casualty_class                 4432
# Sex_of_casualty                4432
# Age_band_of_casualty              0
# Casualty_severity              4432
# ...

# %%
# df["Driving_experience"].info()
df["Driving_experience"] =df["Driving_experience"].fillna(df["Driving_experience"].mode()[0])

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df.sample(5)
# Out:
#           Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 2367  16:00:00      Sunday              18-30          Male
# 7590  19:30:00    Thursday              18-30          Male
# 9279  21:55:00   Wednesday           Under 18          Male
# 6245  22:17:00    Saturday              18-30          Male
# 7211  18:05:00    Thursday              31-50          Male
#
#        Educational_level Vehicle_driver_relation Driving_experience  \
# 2367   Elementary school                Employee                 10
# 7590  Junior high school                Employee                1-2
# 9279   Elementary school                   Owner                 10
# 6245  Junior high school                   Owner                2-5
# 7211  Junior high school                Employee                 10
#
#      Type_of_vehicle Owner_of_vehicle Defect_of_vehicle  ...  \
# 2367  Lorry (11?40Q)     Organization         No defect  ...
# 7590            Taxi            Owner               NaN  ...
# ...

# %%
# df['Day_of_week'] = df['Day_of_week'].astype("category")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[309], line 2
#       1 # df['Day_of_week'] = df['Day_of_week'].astype("category")
# ----> 2 df['Day_of_week'] = df['Day_of_week'].as_ordered()
#
# File ~\anaconda\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'as_ordered'

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df['Sex_of_driver'] = df['Sex_of_driver'].astype("category")

# %%
df['Educational_level'] = df['Educational_level'].astype("category")

# %%
# Vehicle_driver_relation
df['Vehicle_driver_relation'] = df['Vehicle_driver_relation'].astype("category")

# %%
df['Owner_of_vehicle'] = df['Owner_of_vehicle'].astype("category")

# %%
df['Vehicle_movement'] = df['Vehicle_movement'].astype("category")

# %%
df['Sex_of_casualty'] = df['Sex_of_casualty'].astype("category")

# %%
df['Age_band_of_driver'] = df['Age_band_of_driver'].str.replace("Under "," ")

df[['lower_age','upper_age']] = df['Age_band_of_driver'].str.split('-', expand = True) 
df['lower_age'] = df['lower_age'].astype(int) 
df['upper_age'] =df['upper_age'].astype(int)

# %%
df['upper_age'] 
df['lower_age']

# %% [markdown]
# after this step we can calculate the relationship between age and sex of drive

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12291.000000          12291.000000
# mean                      2.040599              1.548287
# std                       0.688907              1.007381
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
# sns.scatterplot(x = "Day_of_week" , y="Sex_of_driver", data = df)

# sns.barplot(x = "Day_of_week" , y="Time" , data = df);
# sns.regplot(x = "Day_of_week" , y = 'Number_of_vehicles_involved' ,data = df)
import matplotlib.pyplot as plt
df.Number_of_vehicles_involved.plot(kind = 'bar')

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
# import seaborn as sns 
# sns.heatmap(df.corr())

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %% [markdown]
# must study more ..
# thank you
